# %%
#Import the random module and numpy
import random
import numpy as np
from config import weather_api_key
import requests
import pandas as pd

# %%
#Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,90,size = 2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list. Unzips the latitudes and longitudes
coordinates = list(lat_lngs)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
## Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 760

# %%
# Create an empty list to hold the weather data.
city_data = []
#Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if(i%50 == 0 and i>=50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

     # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country":city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# d. Skipping...
# Processing Record 6 of Set 7 | airai
# Processing Record 7 of Set 7 | northam
# Processing Record 8 of Set 7 | tautira
# Processing Record 9 of Set 7 | alofi
# Processing Record 10 of Set 7 | half moon bay
# Processing Record 11 of Set 7 | san patricio
# Processing Record 12 of Set 7 | ishigaki
# Processing Record 13 of Set 7 | bonnyville
# Processing Record 14 of Set 7 | anloga
# Processing Record 15 of Set 7 | thompson
# Processing Record 16 of Set 7 | karamay
# City not found. Skipping...
# Processing Record 17 of Set 7 | xinqing
# Processing Record 18 of Set 7 | ubajara
# Processing Record 19 of Set 7 | sibiti
# Processing Record 20 of Set 7 | gabas
# Processing Record 21 of Set 7 | aswan
# Processing Record 22 of Set 7 | vila franca do campo
# Processing Record 23 of Set 7 | lagos
# Processing Record 24 of Set 7 | ahipara
# Processing Record 25 of Set 7 | hasaki
# Processing Record 26 of Set 7 | felidhoo
# City not found. Skipping...
# Processing Record 27 of Set 7 | beni
# Processing Record 28 of Set 7 | havoysund
# Processing Record 29 of Set 7 | bambous virieux
# Processing Record 30 of Set 7 | estelle
# Processing Record 31 of Set 7 | oxford
# Processing Record 32 of Set 7 | inuvik
# Processing Record 33 of Set 7 | san jeronimo
# Processing Record 34 of Set 7 | qaqortoq
# Processing Record 35 of Set 7 | yar-sale
# Processing Record 36 of Set 7 | cap malheureux
# Processing Record 37 of Set 7 | salamanca
# Processing Record 38 of Set 7 | igboho
# Processing Record 39 of Set 7 | grand-santi
# Processing Record 40 of Set 7 | maceio
# Processing Record 41 of Set 7 | saldanha
# Processing Record 42 of Set 7 | margate
# Processing Record 43 of Set 7 | lata
# Processing Record 44 of Set 7 | nam tha
# City not found. Skipping...
# Processing Record 45 of Set 7 | poronaysk
# Processing Record 46 of Set 7 | berlevag
# Processing Record 47 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 48 of Set 7 | san cristobal
# Processing Record 49 of Set 7 | berdsk
# Processing Record 50 of Set 7 | derbent
# Processing Record 1 of Set 8 | jinxiang
# Processing Record 2 of Set 8 | upernavik
# Processing Record 3 of Set 8 | maragogi
# Processing Record 4 of Set 8 | salalah
# Processing Record 5 of Set 8 | shagonar
# Processing Record 6 of Set 8 | sapele
# Processing Record 7 of Set 8 | saint anthony
# Processing Record 8 of Set 8 | vanimo
# Processing Record 9 of Set 8 | alta floresta
# Processing Record 10 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 11 of Set 8 | goderich
# Processing Record 12 of Set 8 | manggar
# Processing Record 13 of Set 8 | santa rita
# Processing Record 14 of Set 8 | boa vista
# Processing Record 15 of Set 8 | tilichiki
# Processing Record 16 of Set 8 | seoul
# Processing Record 17 of Set 8 | gold coast
# Processing Record 18 of Set 8 | muros
# Processing Record 19 of Set 8 | kavaratti
# Processing Record 20 of Set 8 | luino
# Processing Record 21 of Set 8 | iqaluit
# Processing Record 22 of Set 8 | sungaipenuh
# Processing Record 23 of Set 8 | port-gentil
# Processing Record 24 of Set 8 | caravelas
# Processing Record 25 of Set 8 | kurilsk
# Processing Record 26 of Set 8 | san andres
# Processing Record 27 of Set 8 | punta de bombon
# Processing Record 28 of Set 8 | manukan
# Processing Record 29 of Set 8 | douglas
# Processing Record 30 of Set 8 | kitgum
# Processing Record 31 of Set 8 | yumen
# Processing Record 32 of Set 8 | los llanos de aridane
# Processing Record 33 of Set 8 | mannarakkat
# Processing Record 34 of Set 8 | southbridge
# Processing Record 35 of Set 8 | mashhad
# Processing Record 36 of Set 8 | leh
# Processing Record 37 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 38 of Set 8 | olbia
# Processing Record 39 of Set 8 | ornskoldsvik
# Processing Record 40 of Set 8 | bethel
# Processing Record 41 of Set 8 | auki
# Processing Record 42 of Set 8 | carauari
# Processing Record 43 of Set 8 | valparaiso
# Processing Record 44 of Set 8 | palauig
# Processing Record 45 of Set 8 | bonthe
# Processing Record 46 of Set 8 | lady frere
# Processing Record 47 of Set 8 | sakakah
# Processing Record 48 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 49 of Set 8 | yeniseysk
# Processing Record 50 of Set 8 | north platte
# Processing Record 1 of Set 9 | ferrol
# Processing Record 2 of Set 9 | port blair
# Processing Record 3 of Set 9 | leshukonskoye
# Processing Record 4 of Set 9 | berdavan
# Processing Record 5 of Set 9 | ribeira grande
# Processing Record 6 of Set 9 | lengshuijiang
# Processing Record 7 of Set 9 | naze
# Processing Record 8 of Set 9 | yomitan
# City not found. Skipping...
# Processing Record 9 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 9 | semnan
# Processing Record 11 of Set 9 | mhlume
# Processing Record 12 of Set 9 | saint george
# Processing Record 13 of Set 9 | villazon
# Processing Record 14 of Set 9 | coquimbo
# Processing Record 15 of Set 9 | ulladulla
# Processing Record 16 of Set 9 | masunga
# Processing Record 17 of Set 9 | samsun
# Processing Record 18 of Set 9 | olga
# Processing Record 19 of Set 9 | williamsport
# Processing Record 20 of Set 9 | babanusah
# City not found. Skipping...
# Processing Record 21 of Set 9 | elban
# Processing Record 22 of Set 9 | nyurba
# Processing Record 23 of Set 9 | walvis bay
# Processing Record 24 of Set 9 | maraa
# Processing Record 25 of Set 9 | tendukheda
# Processing Record 26 of Set 9 | rawson
# Processing Record 27 of Set 9 | lyngseidet
# Processing Record 28 of Set 9 | kumluca
# Processing Record 29 of Set 9 | perth
# Processing Record 30 of Set 9 | vitim
# Processing Record 31 of Set 9 | cidreira
# Processing Record 32 of Set 9 | huarmey
# Processing Record 33 of Set 9 | waitati
# Processing Record 34 of Set 9 | palana
# Processing Record 35 of Set 9 | baraboo
# Processing Record 36 of Set 9 | bentiu
# Processing Record 37 of Set 9 | luena
# Processing Record 38 of Set 9 | ewing
# Processing Record 39 of Set 9 | teya
# Processing Record 40 of Set 9 | paamiut
# Processing Record 41 of Set 9 | gizo
# Processing Record 42 of Set 9 | kiruna
# Processing Record 43 of Set 9 | ibra
# Processing Record 44 of Set 9 | miastko
# Processing Record 45 of Set 9 | kyren
# Processing Record 46 of Set 9 | kazachinskoye
# Processing Record 47 of Set 9 | arroio dos ratos
# Processing Record 48 of Set 9 | barahona
# Processing Record 49 of Set 9 | codrington
# Processing Record 50 of Set 9 | ivanteyevka
# Processing Record 1 of Set 10 | smithers
# Processing Record 2 of Set 10 | namanga
# Processing Record 3 of Set 10 | yankton
# Processing Record 4 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 5 of Set 10 | vaitape
# Processing Record 6 of Set 10 | lipari
# Processing Record 7 of Set 10 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 8 of Set 10 | noumea
# Processing Record 9 of Set 10 | coralville
# Processing Record 10 of Set 10 | beisfjord
# Processing Record 11 of Set 10 | huilong
# Processing Record 12 of Set 10 | valentin gomez farias
# Processing Record 13 of Set 10 | tura
# Processing Record 14 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 15 of Set 10 | azangaro
# Processing Record 16 of Set 10 | souillac
# Processing Record 17 of Set 10 | ossora
# Processing Record 18 of Set 10 | savalou
# Processing Record 19 of Set 10 | dryden
# Processing Record 20 of Set 10 | nakhon si thammarat
# Processing Record 21 of Set 10 | hirara
# Processing Record 22 of Set 10 | kaabong
# Processing Record 23 of Set 10 | buon me thuot
# City not found. Skipping...
# Processing Record 24 of Set 10 | bodden town
# Processing Record 25 of Set 10 | verkh-tula
# Processing Record 26 of Set 10 | jijiang
# Processing Record 27 of Set 10 | klaksvik
# Processing Record 28 of Set 10 | algiers
# Processing Record 29 of Set 10 | manturovo
# Processing Record 30 of Set 10 | apam
# Processing Record 31 of Set 10 | edd
# Processing Record 32 of Set 10 | iwanai
# Processing Record 33 of Set 10 | rehburg-loccum
# Processing Record 34 of Set 10 | dingle
# Processing Record 35 of Set 10 | marsala
# Processing Record 36 of Set 10 | trapani
# Processing Record 37 of Set 10 | keroka
# Processing Record 38 of Set 10 | filadelfia
# Processing Record 39 of Set 10 | abaza
# Processing Record 40 of Set 10 | oliver
# Processing Record 41 of Set 10 | galle
# Processing Record 42 of Set 10 | shenzhen
# Processing Record 43 of Set 10 | zaykovo
# Processing Record 44 of Set 10 | nanortalik
# Processing Record 45 of Set 10 | jacareacanga
# Processing Record 46 of Set 10 | mangai
# Processing Record 47 of Set 10 | tahe
# Processing Record 48 of Set 10 | waingapu
# Processing Record 49 of Set 10 | ginir
# Processing Record 50 of Set 10 | meulaboh
# Processing Record 1 of Set 11 | mehamn
# Processing Record 2 of Set 11 | mandalgovi
# Processing Record 3 of Set 11 | greensburg
# Processing Record 4 of Set 11 | arona
# Processing Record 5 of Set 11 | ust-ordynskiy
# Processing Record 6 of Set 11 | andenes
# Processing Record 7 of Set 11 | clearlake
# Processing Record 8 of Set 11 | kiunga
# Processing Record 9 of Set 11 | veliko gradiste
# Processing Record 10 of Set 11 | husavik
# Processing Record 11 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 12 of Set 11 | turlock
# Processing Record 13 of Set 11 | takab
# Processing Record 14 of Set 11 | rocha
# Processing Record 15 of Set 11 | toulepleu
# City not found. Skipping...
# Processing Record 16 of Set 11 | taunton
# Processing Record 17 of Set 11 | livingston
# Processing Record 18 of Set 11 | wukari
# Processing Record 19 of Set 11 | devarkonda
# Processing Record 20 of Set 11 | poya
# Processing Record 21 of Set 11 | aketi
# Processing Record 22 of Set 11 | nioro
# Processing Record 23 of Set 11 | charters towers
# Processing Record 24 of Set 11 | trincomalee
# Processing Record 25 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 26 of Set 11 | yefimovskiy
# City not found. Skipping...
# Processing Record 27 of Set 11 | fatehpur
# Processing Record 28 of Set 11 | port lincoln
# Processing Record 29 of Set 11 | tanout
# Processing Record 30 of Set 11 | tomatlan
# Processing Record 31 of Set 11 | itarema
# Processing Record 32 of Set 11 | soyo
# Processing Record 33 of Set 11 | bousso
# Processing Record 34 of Set 11 | saint-augustin
# Processing Record 35 of Set 11 | baglung
# Processing Record 36 of Set 11 | verkhnyaya inta
# Processing Record 37 of Set 11 | najran
# Processing Record 38 of Set 11 | contamana
# Processing Record 39 of Set 11 | karratha
# Processing Record 40 of Set 11 | conde
# Processing Record 41 of Set 11 | myitkyina
# Processing Record 42 of Set 11 | makakilo city
# Processing Record 43 of Set 11 | wuwei
# Processing Record 44 of Set 11 | vilhena
# Processing Record 45 of Set 11 | raymond
# Processing Record 46 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 47 of Set 11 | chapais
# Processing Record 48 of Set 11 | obihiro
# Processing Record 49 of Set 11 | kembolcha
# Processing Record 50 of Set 11 | grindavik
# Processing Record 1 of Set 12 | sao miguel
# Processing Record 2 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 3 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 12 | adre
# Processing Record 5 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 6 of Set 12 | anori
# Processing Record 7 of Set 12 | roald
# Processing Record 8 of Set 12 | kapuskasing
# Processing Record 9 of Set 12 | aklavik
# Processing Record 10 of Set 12 | emba
# Processing Record 11 of Set 12 | luwuk
# Processing Record 12 of Set 12 | silver city
# Processing Record 13 of Set 12 | flin flon
# Processing Record 14 of Set 12 | bereda
# Processing Record 15 of Set 12 | belomorsk
# Processing Record 16 of Set 12 | kavieng
# Processing Record 17 of Set 12 | belmonte
# Processing Record 18 of Set 12 | bowling green
# Processing Record 19 of Set 12 | miyako
# Processing Record 20 of Set 12 | fare
# Processing Record 21 of Set 12 | strezhevoy
# Processing Record 22 of Set 12 | treinta y tres
# Processing Record 23 of Set 12 | naberera
# Processing Record 24 of Set 12 | phuket
# Processing Record 25 of Set 12 | barcelona
# Processing Record 26 of Set 12 | abrau-dyurso
# Processing Record 27 of Set 12 | bordighera
# Processing Record 28 of Set 12 | rudnogorsk
# Processing Record 29 of Set 12 | omboue
# Processing Record 30 of Set 12 | cockburn town
# Processing Record 31 of Set 12 | kolokani
# Processing Record 32 of Set 12 | nizwa
# Processing Record 33 of Set 12 | west bay
# Processing Record 34 of Set 12 | ranau
# Processing Record 35 of Set 12 | taoudenni
# Processing Record 36 of Set 12 | ancud
# Processing Record 37 of Set 12 | sitka
# Processing Record 38 of Set 12 | ahuimanu
# Processing Record 39 of Set 12 | montorio al vomano
# Processing Record 40 of Set 12 | harper
# Processing Record 41 of Set 12 | ternate
# Processing Record 42 of Set 12 | develi
# Processing Record 43 of Set 12 | praia da vitoria
# Processing Record 44 of Set 12 | tala
# Processing Record 45 of Set 12 | grenville
# Processing Record 46 of Set 12 | mpongwe
# Processing Record 47 of Set 12 | anuchino
# Processing Record 48 of Set 12 | felanitx
# Processing Record 49 of Set 12 | vengerovo
# Processing Record 50 of Set 12 | los alamos
# Processing Record 1 of Set 13 | ayan
# Processing Record 2 of Set 13 | itaituba
# Processing Record 3 of Set 13 | nowe miasto lubawskie
# Processing Record 4 of Set 13 | biak
# Processing Record 5 of Set 13 | jizan
# Processing Record 6 of Set 13 | port macquarie
# Processing Record 7 of Set 13 | angoche
# Processing Record 8 of Set 13 | kruisfontein
# Processing Record 9 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 10 of Set 13 | miranorte
# City not found. Skipping...
# Processing Record 11 of Set 13 | porto velho
# Processing Record 12 of Set 13 | saint-georges
# Processing Record 13 of Set 13 | bingol
# Processing Record 14 of Set 13 | san luis
# Processing Record 15 of Set 13 | taksimo
# Processing Record 16 of Set 13 | dubbo
# Processing Record 17 of Set 13 | santa isabel
# Processing Record 18 of Set 13 | oistins
# Processing Record 19 of Set 13 | tromso
# Processing Record 20 of Set 13 | sisophon
# Processing Record 21 of Set 13 | maneadero
# Processing Record 22 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 13 | sedona
# Processing Record 24 of Set 13 | macusani
# Processing Record 25 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 26 of Set 13 | west lafayette
# Processing Record 27 of Set 13 | dalby
# Processing Record 28 of Set 13 | chara
# Processing Record 29 of Set 13 | jalu
# Processing Record 30 of Set 13 | uyuni
# Processing Record 31 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 32 of Set 13 | dokka
# Processing Record 33 of Set 13 | gravdal
# Processing Record 34 of Set 13 | arlit
# Processing Record 35 of Set 13 | velykyy burluk
# Processing Record 36 of Set 13 | russell
# Processing Record 37 of Set 13 | maloshuyka
# City not found. Skipping...
# Processing Record 38 of Set 13 | zabol
# Processing Record 39 of Set 13 | tiznit
# Processing Record 40 of Set 13 | boke
# Processing Record 41 of Set 13 | deniliquin
# Processing Record 42 of Set 13 | kinston
# Processing Record 43 of Set 13 | boden
# Processing Record 44 of Set 13 | lake city
# Processing Record 45 of Set 13 | wilmington
# Processing Record 46 of Set 13 | lagoa
# Processing Record 47 of Set 13 | camacha
# Processing Record 48 of Set 13 | sehithwa
# Processing Record 49 of Set 13 | cabra
# Processing Record 50 of Set 13 | setermoen
# Processing Record 1 of Set 14 | laem sing
# Processing Record 2 of Set 14 | katima mulilo
# Processing Record 3 of Set 14 | shubarkuduk
# Processing Record 4 of Set 14 | savannah bight
# Processing Record 5 of Set 14 | nargana
# Processing Record 6 of Set 14 | american fork
# Processing Record 7 of Set 14 | cognac
# Processing Record 8 of Set 14 | kovvur
# Processing Record 9 of Set 14 | posse
# Processing Record 10 of Set 14 | vostok
# Processing Record 11 of Set 14 | anadyr
# Processing Record 12 of Set 14 | kathu
# Processing Record 13 of Set 14 | urucara
# Processing Record 14 of Set 14 | canoinhas
# Processing Record 15 of Set 14 | egvekinot
# Processing Record 16 of Set 14 | kachiry
# Processing Record 17 of Set 14 | alyangula
# Processing Record 18 of Set 14 | lamu
# Processing Record 19 of Set 14 | areia branca
# Processing Record 20 of Set 14 | pascoag
# Processing Record 21 of Set 14 | nizip
# Processing Record 22 of Set 14 | carutapera
# Processing Record 23 of Set 14 | lipno
# Processing Record 24 of Set 14 | fertod
# Processing Record 25 of Set 14 | marzuq
# Processing Record 26 of Set 14 | carroll
# Processing Record 27 of Set 14 | mandali
# Processing Record 28 of Set 14 | orsha
# Processing Record 29 of Set 14 | cacoal
# Processing Record 30 of Set 14 | luanda
# Processing Record 31 of Set 14 | kabanjahe
# Processing Record 32 of Set 14 | bolshiye uki
# City not found. Skipping...
# Processing Record 33 of Set 14 | samoded
# Processing Record 34 of Set 14 | rehoboth
# Processing Record 35 of Set 14 | norrkoping
# Processing Record 36 of Set 14 | pindiga
# Processing Record 37 of Set 14 | suamico
# Processing Record 38 of Set 14 | hofn
# Processing Record 39 of Set 14 | lasa
# Processing Record 40 of Set 14 | terrace
# Processing Record 41 of Set 14 | srednekolymsk
# Processing Record 42 of Set 14 | sao felix do xingu
# Processing Record 43 of Set 14 | boshnyakovo
# Processing Record 44 of Set 14 | fujinomiya
# Processing Record 45 of Set 14 | daru
# Processing Record 46 of Set 14 | khilok
# Processing Record 47 of Set 14 | umm lajj
# Processing Record 48 of Set 14 | fortuna foothills
# Processing Record 49 of Set 14 | lorengau
# Processing Record 50 of Set 14 | andevoranto
# City not found. Skipping...
# Processing Record 1 of Set 15 | urumqi
# Processing Record 2 of Set 15 | amga
# Processing Record 3 of Set 15 | forestville
# Processing Record 4 of Set 15 | tokzar
# City not found. Skipping...
# Processing Record 5 of Set 15 | solton
# Processing Record 6 of Set 15 | chodavaram
# Processing Record 7 of Set 15 | sawakin
# Processing Record 8 of Set 15 | kodinsk
# Processing Record 9 of Set 15 | beitbridge
# Processing Record 10 of Set 15 | khorramabad
# Processing Record 11 of Set 15 | oyama
# Processing Record 12 of Set 15 | detva
# Processing Record 13 of Set 15 | kaele
# Processing Record 14 of Set 15 | korla
# Processing Record 15 of Set 15 | dabola
# Processing Record 16 of Set 15 | vung tau
# Processing Record 17 of Set 15 | hvide sande
# Processing Record 18 of Set 15 | camabatela
# Processing Record 19 of Set 15 | mayo
# Processing Record 20 of Set 15 | kasongo-lunda
# Processing Record 21 of Set 15 | suileng
# Processing Record 22 of Set 15 | uray
# Processing Record 23 of Set 15 | alihe
# Processing Record 24 of Set 15 | aykhal
# Processing Record 25 of Set 15 | avallon
# Processing Record 26 of Set 15 | yenagoa
# Processing Record 27 of Set 15 | brae
# Processing Record 28 of Set 15 | moranbah
# Processing Record 29 of Set 15 | buritizeiro
# Processing Record 30 of Set 15 | neuquen
# Processing Record 31 of Set 15 | khasan
# Processing Record 32 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 33 of Set 15 | nandi
# Processing Record 34 of Set 15 | joao pinheiro
# Processing Record 35 of Set 15 | eureka
# Processing Record 36 of Set 15 | asfi
# Processing Record 37 of Set 15 | olinda
# Processing Record 38 of Set 15 | williams lake
# Processing Record 39 of Set 15 | yangambi
# Processing Record 40 of Set 15 | channel-port aux basques
# Processing Record 41 of Set 15 | ixtapa
# Processing Record 42 of Set 15 | verkh-usugli
# Processing Record 43 of Set 15 | butterworth
# Processing Record 44 of Set 15 | bowen
# Processing Record 45 of Set 15 | santo antonio do ica
# Processing Record 46 of Set 15 | litovko
# Processing Record 47 of Set 15 | kissimmee
# Processing Record 48 of Set 15 | baykit
# Processing Record 49 of Set 15 | correntina
# Processing Record 50 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 16 | mildura
# Processing Record 2 of Set 16 | kandrian
# Processing Record 3 of Set 16 | port hedland
# Processing Record 4 of Set 16 | puerto palomas
# Processing Record 5 of Set 16 | westport
# Processing Record 6 of Set 16 | new iberia
# Processing Record 7 of Set 16 | tommot
# Processing Record 8 of Set 16 | bogalusa
# Processing Record 9 of Set 16 | bairiki
# Processing Record 10 of Set 16 | melito di porto salvo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                       City Country      Lat       Lng  Max Temp  Humidity  \
# 0                   Xinmin      CN  41.9908  122.8253     26.60        86
# 1                      Gat      IL  31.6100   34.7642     57.99       100
# 2                   Castro      BR -24.7911  -50.0119     60.55        58
# 3             Norman Wells      CA  65.2820 -126.8329    -29.20        68
# 4               Nikolskoye      RU  59.7035   30.7861     10.00        78
# ..                     ...     ...      ...       ...       ...       ...
# 684             New Iberia      US  30.0035  -91.8187     51.01        87
# 685                 Tommot      RU  58.9564  126.2925    -20.04        83
# 686               Bogalusa      US  30.7910  -89.8487     46.40        87
# 687                Bairiki      KI   1.3292  172.9752     86.00        70
# 688  Melito Di Porto Salvo      IT  37.9222   15.7714     60.01        82
#
#      Cloudiness  Wind Speed Current Description
# 0            24        4.47                mist
# 1            58        3.27       broken clouds
# 2             0        3.33           clear sky
# 3            20        4.61          few clouds
# 4            75       11.18          light snow
# ..          ...         ...                 ...
# 684          90        6.91     overcast clouds
# 685         100        3.00     overcast clouds
# 686          90        5.50     overcast clouds
# 687          75        9.22       broken clouds
# 688          38        4.61    scattered clouds
#
# [689 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
